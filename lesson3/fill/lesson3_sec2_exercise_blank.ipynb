# %% [markdown]
# # Lesson3 系列データで分類・予測させてみよう（RNN, LSTM）

# %% [markdown]
# ## 目次
#
# - Section1 Checkクイズの解答
# - Section2. 実装①
#     - 2.0 データの用意
#     - 2.1 モデル構築
#     - 2.2 モデルの学習
#     - 2.3 モデルによる予測
#     - 2.4 モデルの可視化

# %% [markdown]
# ## Section1 Checkクイズの解答
#
# 問題1: 2, 問題2: 3

# %% [markdown]
# ## Section2 実装①
#
# ここでは、以下のページのECGによる波形データセットECG5000をRNNで学習し、分類を行ってみましょう。
#
# http://timeseriesclassification.com/description.php?Dataset=ECG5000
#
# このデータセットは、ECGの計測値140時点分とその系列に対する分類（1～5）で1データとなっており、全体で5000データが含まれています。

# %% [markdown]
# ### 2.0 データの用意
#
# まずはデータを読み込みましょう。arffという形式で保存されているため、`scipy.io.loadarff`関数でロードします。
#
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.io.arff.loadarff.html

# %%
# %matplotlib inline

from scipy.io import arff
import numpy as np

dataset, meta = arff.loadarff('/root/userspace/public/lesson3/data/ECG5000.arff')

ds = np.asarray(dataset.tolist(), dtype=np.float32)
x_dataset = ds[:, :140]
y_dataset = np.asarray(ds[:,-1].tolist(), dtype=np.int8)-1

# %% [markdown]
# 実際に表示してみて、様子を確認しておきましょう。

# %%
import matplotlib.pyplot as plt

N = 10
print(y_dataset[:N])
obj = plt.plot(x_dataset[:N].T)
plt.legend(obj, [str(n) for n in range(N)])
# Out:
# [0 0 0 1 0 0 0 1 0 0]

# %% [markdown]
# 確かに、分類結果が異なる3,7番はt=100付近でピークを持たないことが見て取れます。

# %% [markdown]
# 続いて、データセットを訓練用とテスト用に分割します。

# %%
# 訓練データとテストデータを分割（＋データの整形）

from sklearn.model_selection import train_test_split
from keras.utils import to_categorical

x_train, x_test, y_train, y_test = train_test_split(x_dataset[:,:,np.newaxis], to_categorical(y_dataset), test_size=0.2, random_state=42)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### 2.1 モデル構築
#
# ここでは、先程紹介したSimpleRNNを使用してモデルを構築します。

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, SimpleRNN

hid_dim = 10

# SimpleRNNにDenseを接続し、分類
model = Sequential()

model.add(SimpleRNN(hid_dim, input_shape=x_train.shape[1:])) # input_shape=(系列長T, x_tの次元), output_shape=(系列長T, units(=hid_dim))
model.add(Dense(y_train.shape[1], activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# ### 2.2 モデルの学習

# %%
model.fit(x_train, y_train, epochs=50, batch_size=100, verbose=2, validation_split=0.2)
# Out:
# Train on 3200 samples, validate on 800 samples
# Epoch 1/50
#  - 5s - loss: 1.4621 - acc: 0.3791 - val_loss: 1.2905 - val_acc: 0.4675
# Epoch 2/50
#  - 2s - loss: 1.1589 - acc: 0.5966 - val_loss: 1.0331 - val_acc: 0.7250
# Epoch 3/50
#  - 2s - loss: 0.9314 - acc: 0.7972 - val_loss: 0.8429 - val_acc: 0.8200
# Epoch 4/50
#  - 2s - loss: 0.7713 - acc: 0.8422 - val_loss: 0.7148 - val_acc: 0.8412
# Epoch 5/50
#  - 2s - loss: 0.6615 - acc: 0.8631 - val_loss: 0.6219 - val_acc: 0.8550
# Epoch 6/50
#  - 2s - loss: 0.5854 - acc: 0.8756 - val_loss: 0.5499 - val_acc: 0.8725
# Epoch 7/50
#  - 2s - loss: 0.5276 - acc: 0.8837 - val_loss: 0.5023 - val_acc: 0.8838
# Epoch 8/50
#  - 2s - loss: 0.4807 - acc: 0.8906 - val_loss: 0.4503 - val_acc: 0.8975
# Epoch 9/50
#  - 2s - loss: 0.4591 - acc: 0.8931 - val_loss: 0.4407 - val_acc: 0.8937
# Epoch 10/50
#  - 2s - loss: 0.4448 - acc: 0.8956 - val_loss: 0.4249 - val_acc: 0.8963
# Epoch 11/50
#  - 2s - loss: 0.4328 - acc: 0.8972 - val_loss: 0.4116 - val_acc: 0.9013
# Epoch 12/50
#  - 2s - loss: 0.4228 - acc: 0.8978 - val_loss: 0.3995 - val_acc: 0.9038
# Epoch 13/50
#  - 2s - loss: 0.4141 - acc: 0.8988 - val_loss: 0.3870 - val_acc: 0.9050
# Epoch 14/50
#  - 2s - loss: 0.4071 - acc: 0.8997 - val_loss: 0.3787 - val_acc: 0.9062
# Epoch 15/50
#  - 2s - loss: 0.4007 - acc: 0.9003 - val_loss: 0.3706 - val_acc: 0.9062
# Epoch 16/50
#  - 2s - loss: 0.3956 - acc: 0.9013 - val_loss: 0.3644 - val_acc: 0.9088
# Epoch 17/50
#  - 2s - loss: 0.3910 - acc: 0.9022 - val_loss: 0.3595 - val_acc: 0.9100
# Epoch 18/50
#  - 2s - loss: 0.3876 - acc: 0.9025 - val_loss: 0.3552 - val_acc: 0.9088
# Epoch 19/50
#  - 2s - loss: 0.3843 - acc: 0.9028 - val_loss: 0.3512 - val_acc: 0.9138
# Epoch 20/50
#  - 2s - loss: 0.3813 - acc: 0.9038 - val_loss: 0.3478 - val_acc: 0.9138
# Epoch 21/50
#  - 2s - loss: 0.3785 - acc: 0.9037 - val_loss: 0.3449 - val_acc: 0.9150
# Epoch 22/50
#  - 2s - loss: 0.3758 - acc: 0.9041 - val_loss: 0.3421 - val_acc: 0.9150
# Epoch 23/50
#  - 2s - loss: 0.3735 - acc: 0.9041 - val_loss: 0.3397 - val_acc: 0.9150
# Epoch 24/50
#  - 2s - loss: 0.3716 - acc: 0.9044 - val_loss: 0.3368 - val_acc: 0.9125
# Epoch 25/50
#  - 2s - loss: 0.3687 - acc: 0.9056 - val_loss: 0.3336 - val_acc: 0.9138
# Epoch 26/50
#  - 2s - loss: 0.3664 - acc: 0.9066 - val_loss: 0.3317 - val_acc: 0.9138
# Epoch 27/50
#  - 2s - loss: 0.3645 - acc: 0.9072 - val_loss: 0.3301 - val_acc: 0.9150
# Epoch 28/50
#  - 2s - loss: 0.3624 - acc: 0.9069 - val_loss: 0.3276 - val_acc: 0.9150
# Epoch 29/50
#  - 2s - loss: 0.3611 - acc: 0.9062 - val_loss: 0.3260 - val_acc: 0.9150
# Epoch 30/50
#  - 2s - loss: 0.3600 - acc: 0.9062 - val_loss: 0.3246 - val_acc: 0.9150
# Epoch 31/50
#  - 2s - loss: 0.3578 - acc: 0.9072 - val_loss: 0.3232 - val_acc: 0.9163
# Epoch 32/50
#  - 2s - loss: 0.3578 - acc: 0.9075 - val_loss: 0.3215 - val_acc: 0.9163
# Epoch 33/50
#  - 2s - loss: 0.3557 - acc: 0.9075 - val_loss: 0.3207 - val_acc: 0.9150
# Epoch 34/50
#  - 2s - loss: 0.3555 - acc: 0.9069 - val_loss: 0.3195 - val_acc: 0.9150
# Epoch 35/50
#  - 2s - loss: 0.3534 - acc: 0.9075 - val_loss: 0.3185 - val_acc: 0.9150
# Epoch 36/50
#  - 2s - loss: 0.3524 - acc: 0.9075 - val_loss: 0.3173 - val_acc: 0.9150
# Epoch 37/50
#  - 2s - loss: 0.3526 - acc: 0.9075 - val_loss: 0.3156 - val_acc: 0.9163
# Epoch 38/50
#  - 2s - loss: 0.3511 - acc: 0.9078 - val_loss: 0.3147 - val_acc: 0.9150
# Epoch 39/50
#  - 2s - loss: 0.3505 - acc: 0.9081 - val_loss: 0.3144 - val_acc: 0.9150
# Epoch 40/50
#  - 2s - loss: 0.3483 - acc: 0.9091 - val_loss: 0.3185 - val_acc: 0.9138
# Epoch 41/50
#  - 2s - loss: 0.3514 - acc: 0.9066 - val_loss: 0.3161 - val_acc: 0.9163
# Epoch 42/50
#  - 2s - loss: 0.3531 - acc: 0.9075 - val_loss: 0.3119 - val_acc: 0.9163
# Epoch 43/50
#  - 2s - loss: 0.3492 - acc: 0.9088 - val_loss: 0.3199 - val_acc: 0.9125
# Epoch 44/50
#  - 2s - loss: 0.3518 - acc: 0.9081 - val_loss: 0.3176 - val_acc: 0.9125
# Epoch 45/50
#  - 2s - loss: 0.3486 - acc: 0.9091 - val_loss: 0.3159 - val_acc: 0.9125
# Epoch 46/50
#  - 2s - loss: 0.3452 - acc: 0.9091 - val_loss: 0.3103 - val_acc: 0.9138
# Epoch 47/50
#  - 2s - loss: 0.3441 - acc: 0.9094 - val_loss: 0.3093 - val_acc: 0.9138
# Epoch 48/50
#  - 2s - loss: 0.3448 - acc: 0.9084 - val_loss: 0.3082 - val_acc: 0.9138
# Epoch 49/50
#  - 2s - loss: 0.3444 - acc: 0.9084 - val_loss: 0.3075 - val_acc: 0.9150
# Epoch 50/50
#  - 2s - loss: 0.3438 - acc: 0.9091 - val_loss: 0.3067 - val_acc: 0.9150

# %% [markdown]
# ### 2.3 モデルによる分類精度の評価

# %%
# 性能評価
score = model.evaluate(x_test, y_test, verbose=0)
print('test_loss:', score[0])
print('test_acc:', score[1])
# Out:
# test_loss: 0.342094880104
# test_acc: 0.908

# %% [markdown]
# ### 2.4 モデルの可視化

# %%
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

SVG(model_to_dot(model).create(prog='dot', format='svg'))
